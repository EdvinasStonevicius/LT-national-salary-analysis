# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.stats.multicomp import pairwise_tukeyhsd

# %%
sns.set_theme()

# %%
data = pd.read_csv('../Data/SQLout_employees.csv')

# %%
data2018ft = data.query('arrangement == "FT" & year==2018', inplace=False )[['nace',
                          'esize_class',  'collective',  'gender',
                          'age_class', 'lpk',  'education', 'hourly_rate']]

# %%
def hr_in_categories(dataframe, column):
    """function to estimate if categorical feature is
     an important predictor and if it can be reclassified"""
    sns.boxplot(data=dataframe, x=column, y='hourly_rate')
    plt.ylim(0, 15)
    plt.show();
    tukey = pairwise_tukeyhsd(endog=dataframe['hourly_rate'], 
                        groups=dataframe[column], alpha=0.05)
    print(tukey)
    count = dataframe[column].value_counts()
    print('Value Counts:', count, sep='\n')

# %% [markdown]
# # 'hourly_rate' variation in predictor groups

# %% [markdown]
# ## 'esize_class'

# %%
hr_in_categories(data2018ft, 'esize_class')
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#   1_49 50_249   1.1461   -0.0  1.0218 1.2703   True
#   1_49 GT_250   1.1105   -0.0  0.9942 1.2268   True
# 50_249 GT_250  -0.0356 0.7244 -0.1445 0.0734  False
# ---------------------------------------------------
# Value Counts:
# GT_250    15966
# 50_249    11525
# 1_49       9294
# Name: esize_class, dtype: int64

# %%
reclassify = { '1_49': 0, '50_249': 1, 'GT_250': 1}
data2018ft['esize_class_nc']=data2018ft['esize_class'].replace(reclassify)
data2018ft.drop(columns='esize_class', inplace=True )

# %% [markdown]
# ## 'collective'

# %%
hr_in_categories(data2018ft, 'collective')
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ====================================================
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#      B      C  -0.6311 0.3155 -1.5762   0.314  False
#      B      D   0.2036 0.1214 -0.0335  0.4406  False
#      B      N   -0.094 0.6759 -0.3092  0.1212  False
#      C      D   0.8347 0.0964 -0.0948  1.7641  False
#      C      N   0.5371 0.4417 -0.3871  1.4612  False
#      D      N  -0.2976    0.0  -0.428 -0.1672   True
# ----------------------------------------------------
# Value Counts:
# N    27190
# D     7213
# B     2268
# C      114
# Name: collective, dtype: int64

# %% [markdown]
# Can be droped.

# %%
data2018ft.drop(columns='collective', inplace=True)

# %% [markdown]
# ## 'gender'

# %%
hr_in_categories(data2018ft, 'gender')
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =================================================
# group1 group2 meandiff p-adj lower  upper  reject
# -------------------------------------------------
#      F      M   0.8066  -0.0 0.7283 0.8848   True
# -------------------------------------------------
# Value Counts:
# M    19974
# F    16811
# Name: gender, dtype: int64

# %%
data2018ft = pd.get_dummies(data2018ft,prefix='gen',columns=['gender'] )

# %% [markdown]
# ## 'age_class'

# %%
hr_in_categories(data2018ft, 'age_class')
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ====================================================
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#  14-29  30-39   1.2492    0.0  1.0861  1.4124   True
#  14-29  40-49   0.6221    0.0  0.4595  0.7848   True
#  14-29  50-59  -0.0887 0.5594 -0.2494  0.0721  False
#  14-29    60+  -0.1999 0.0558 -0.4028   0.003  False
#  30-39  40-49  -0.6271    0.0 -0.7893 -0.4649   True
#  30-39  50-59  -1.3379    0.0 -1.4981 -1.1777   True
#  30-39    60+  -1.4492    0.0 -1.6517 -1.2466   True
#  40-49  50-59  -0.7108    0.0 -0.8706  -0.551   True
#  40-49    60+  -0.8221    0.0 -1.0242 -0.6199   True
#  50-59    60+  -0.1113 0.5539 -0.3118  0.0893  False
# ----------------------------------------------------
# Value Counts:
# 50-59    8614
# 40-49    8199
# 30-39    8108
# 14-29    8006
# 60+      3858
# Name: age_class, dtype: int64

# %%
reclassify = { '14-29': 0, '30-39': 2, '40-49': 1, '50-59': 0, '60+': 0}
data2018ft['age_class_nc']=data2018ft['age_class'].map(reclassify)
data2018ft.drop(columns='age_class', inplace=True )

# %% [markdown]
# ## 'education'

# %%
hr_in_categories(data2018ft, 'education')
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =================================================
# group1 group2 meandiff p-adj lower  upper  reject
# -------------------------------------------------
#     G1     G2   0.5137   0.0 0.2433 0.7841   True
#     G1     G3   2.7877  -0.0 2.5094 3.0659   True
#     G1     G4   4.3739  -0.0 4.0892 4.6587   True
#     G2     G3   2.2739  -0.0 2.1614 2.3864   True
#     G2     G4   3.8602  -0.0 3.7325 3.9879   True
#     G3     G4   1.5863  -0.0 1.4427 1.7298   True
# -------------------------------------------------
# Value Counts:
# G2    19371
# G3     9559
# G4     6680
# G1     1175
# Name: education, dtype: int64

# %%
reclassify = { 'G1': 0, 'G2': 1, 'G3': 2, 'G4': 3}
data2018ft['education_nc']=data2018ft['education'].map(reclassify)
data2018ft.drop(columns='education', inplace=True )

# %% [markdown]
# ## 'nace' (high cardinality )

# %%
hr_in_categories(data2018ft, 'nace')
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ====================================================
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#      B      C  -0.5978 0.1723 -1.2794  0.0838  False
#      B      D  -0.0195    1.0 -0.8301  0.7911  False
#      B      E  -1.1563    0.0 -1.9294 -0.3832   True
#      B      F  -0.4738 0.7086 -1.2035  0.2559  False
#      B      G  -1.1443    0.0 -1.8573 -0.4313   True
#      B      H  -1.1689    0.0 -1.8705 -0.4673   True
#      B      I  -2.2757    0.0 -3.0526 -1.4987   True
#      B      J   2.5323    0.0  1.7981  3.2665   True
#      B      K    2.419    0.0  1.6608  3.1772   True
#      B      L  -1.1456 0.0013 -2.0475 -0.2438   True
#      B      M   0.8912 0.0027   0.162  1.6203   True
#      B      N   -1.662    0.0 -2.3826 -0.9413   True
#      B      O    0.118    1.0 -0.6011  0.8371  False
#      B      P  -0.9081 0.0037  -1.664 -0.1523   True
#      B      Q  -0.7209 0.0483 -1.4397 -0.0022   True
#      B      R  -1.6703    0.0  -2.444 -0.8966   True
#      B      S   -1.453    0.0 -2.3042 -0.6018   True
#      C      D   0.5783  0.003  0.1024  1.0542   True
#      C      E  -0.5585 0.0003 -0.9673 -0.1497   True
#      C      F    0.124 0.9971 -0.1953  0.4432  False
#      C      G  -0.5465    0.0 -0.8254 -0.2676   True
#      C      H  -0.5711    0.0 -0.8196 -0.3226   True
#      C      I  -1.6778    0.0 -2.0939 -1.2618   True
#      C      J   3.1301    0.0  2.8007  3.4595   True
#      C      K   3.0168    0.0  2.6369  3.3967   True
#      C      L  -0.5478   0.16 -1.1665  0.0709  False
#      C      M    1.489    0.0  1.1711  1.8068   True
#      C      N  -1.0641    0.0 -1.3621 -0.7662   True
#      C      O   0.7158    0.0  0.4215    1.01   True
#      C      P  -0.3103 0.2605 -0.6855  0.0649  False
#      C      Q  -0.1231  0.993 -0.4166  0.1703  False
#      C      R  -1.0725    0.0 -1.4825 -0.6625   True
#      C      S  -0.8552    0.0 -1.3974  -0.313   True
#      D      E  -1.1368    0.0 -1.7365 -0.5371   True
#      D      F  -0.4543 0.2406 -0.9969  0.0883  False
#      D      G  -1.1248    0.0 -1.6447 -0.6049   True
#      D      H  -1.1494    0.0 -1.6536 -0.6451   True
#      D      I  -2.2561    0.0 -2.8608 -1.6515   True
#      D      J   2.5518    0.0  2.0032  3.1004   True
#      D      K   2.4386    0.0  1.8582  3.0189   True
#      D      L  -1.1261    0.0 -1.8846 -0.3676   True
#      D      M   0.9107    0.0  0.3689  1.4525   True
#      D      N  -1.6424    0.0 -2.1728 -1.1121   True
#      D      O   0.1375    1.0 -0.3908  0.6657  False
#      D      P  -0.8886    0.0 -1.4659 -0.3113   True
#      D      Q  -0.7014 0.0005 -1.2293 -0.1736   True
#      D      R  -1.6508    0.0 -2.2513 -1.0503   True
#      D      S  -1.4335    0.0 -2.1309  -0.736   True
#      E      F   0.6825 0.0001  0.1977  1.1673   True
#      E      G    0.012    1.0 -0.4472  0.4713  False
#      E      H  -0.0126    1.0 -0.4541  0.4289  False
#      E      I  -1.1193    0.0 -1.6727 -0.5659   True
#      E      J   3.6886    0.0  3.1971  4.1802   True
#      E      K   3.5754    0.0  3.0486  4.1021   True
#      E      L   0.0107    1.0 -0.7076   0.729  False
#      E      M   2.0475    0.0  1.5635  2.5314   True
#      E      N  -0.5056 0.0208 -0.9767 -0.0346   True
#      E      O   1.2743    0.0  0.8056   1.743   True
#      E      P   0.2482 0.9746 -0.2752  0.7716  False
#      E      Q   0.4354 0.1052 -0.0329  0.9036  False
#      E      R   -0.514 0.0984 -1.0628  0.0349  False
#      E      S  -0.2967 0.9836 -0.9502  0.3569  False
#      F      G  -0.6705    0.0 -1.0522 -0.2887   True
#      F      H  -0.6951    0.0 -1.0552  -0.335   True
#      F      I  -1.8018    0.0 -2.2928 -1.3109   True
#      F      J   3.0061    0.0  2.5861  3.4262   True
#      F      K   2.8929    0.0  2.4322  3.3536   True
#      F      L  -0.6718 0.0496 -1.3432 -0.0004   True
#      F      M    1.365    0.0  0.9539   1.776   True
#      F      N  -1.1881    0.0  -1.584 -0.7923   True
#      F      O   0.5918    0.0  0.1987  0.9848   True
#      F      P  -0.4343 0.0852 -0.8911  0.0225  False
#      F      Q  -0.2471 0.7562 -0.6396  0.1454  False
#      F      R  -1.1965    0.0 -1.6823 -0.7106   True
#      F      S  -0.9792    0.0 -1.5807 -0.3776   True
#      G      H  -0.0246    1.0 -0.3495  0.3003  False
#      G      I  -1.1314    0.0 -1.5971 -0.6656   True
#      G      J   3.6766    0.0  3.2863  4.0668   True
#      G      K   3.5633    0.0  3.1296   3.997   True
#      G      L  -0.0013    1.0 -0.6545  0.6518  False
#      G      M   2.0354    0.0  1.6549   2.416   True
#      G      N  -0.5177 0.0001 -0.8817 -0.1536   True
#      G      O   1.2622    0.0  0.9012  1.6233   True
#      G      P   0.2362 0.9055 -0.1934  0.6658  False
#      G      Q   0.4233 0.0054  0.0629  0.7838   True
#      G      R   -0.526 0.0084 -0.9863 -0.0657   True
#      G      S  -0.3087 0.9286 -0.8899  0.2725  False
#      H      I  -1.1067    0.0  -1.555 -0.6585   True
#      H      J   3.7012    0.0  3.3321  4.0703   True
#      H      K   3.5879    0.0  3.1731  4.0028   True
#      H      L   0.0233    1.0 -0.6175   0.664  False
#      H      M   2.0601    0.0  1.7011   2.419   True
#      H      N   -0.493 0.0001 -0.8344 -0.1517   True
#      H      O   1.2869    0.0  0.9487   1.625   True
#      H      P   0.2608  0.743 -0.1498  0.6713  False
#      H      Q    0.448 0.0005  0.1105  0.7854   True
#      H      R  -0.5014 0.0096 -0.9439 -0.0588   True
#      H      S  -0.2841 0.9574 -0.8513  0.2832  False
#      I      J   4.8079    0.0  4.3103  5.3056   True
#      I      K   4.6947    0.0  4.1623  5.2271   True
#      I      L     1.13    0.0  0.4076  1.8525   True
#      I      M   3.1668    0.0  2.6767  3.6569   True
#      I      N   0.6137  0.001  0.1363  1.0911   True
#      I      O   2.3936    0.0  1.9185  2.8687   True
#      I      P   1.3675    0.0  0.8385  1.8966   True
#      I      Q   1.5547    0.0  1.0801  2.0293   True
#      I      R   0.6054 0.0164  0.0511  1.1597   True
#      I      S   0.8227 0.0018  0.1646  1.4808   True
#      J      K  -0.1133    1.0  -0.581  0.3545  False
#      J      L  -3.6779    0.0 -4.3542 -3.0017   True
#      J      M  -1.6411    0.0 -2.0601 -1.2221   True
#      J      N  -4.1942    0.0 -4.5983 -3.7902   True
#      J      O  -2.4143    0.0 -2.8157  -2.013   True
#      J      P  -3.4404    0.0 -3.9044 -2.9764   True
#      J      Q  -3.2532    0.0  -3.654 -2.8525   True
#      J      R  -4.2026    0.0 -4.6951   -3.71   True
#      J      S  -3.9853    0.0 -4.5923 -3.3782   True
#      K      L  -3.5647    0.0 -4.2669 -2.8624   True
#      K      M  -1.5279    0.0 -1.9877 -1.0681   True
#      K      N   -4.081    0.0 -4.5272 -3.6348   True
#      K      O  -2.3011    0.0 -2.7448 -1.8574   True
#      K      P  -3.3272    0.0 -3.8283 -2.8261   True
#      K      Q    -3.14    0.0 -3.5832 -2.6968   True
#      K      R  -4.0893    0.0  -4.617 -3.5617   True
#      K      S   -3.872    0.0 -4.5079 -3.2362   True
#      L      M   2.0368    0.0  1.3661  2.7075   True
#      L      N  -0.5163 0.3639 -1.1778  0.1452  False
#      L      O   1.2636    0.0  0.6037  1.9234   True
#      L      P   0.2375 0.9995 -0.4622  0.9372  False
#      L      Q   0.4247 0.7219 -0.2348  1.0842  False
#      L      R  -0.5247 0.4946 -1.2436  0.1943  False
#      L      S  -0.3074 0.9975 -1.1091  0.4944  False
#      M      N  -2.5531    0.0 -2.9478 -2.1584   True
#      M      O  -0.7732    0.0 -1.1651 -0.3813   True
#      M      P  -1.7993    0.0 -2.2552 -1.3434   True
#      M      Q  -1.6121    0.0 -2.0035 -1.2207   True
#      M      R  -2.5614    0.0 -3.0464 -2.0765   True
#      M      S  -2.3441    0.0  -2.945 -1.7433   True
#      N      O   1.7799    0.0   1.404  2.1558   True
#      N      P   0.7538    0.0  0.3116   1.196   True
#      N      Q    0.941    0.0  0.5657  1.3163   True
#      N      R  -0.0083    1.0 -0.4804  0.4637  False
#      N      S    0.209 0.9991 -0.3816  0.7995  False
#      O      P  -1.0261    0.0 -1.4658 -0.5864   True
#      O      Q  -0.8389    0.0 -1.2113 -0.4665   True
#      O      R  -1.7882    0.0  -2.258 -1.3185   True
#      O      S  -1.5709    0.0 -2.1596 -0.9822   True
#      P      Q   0.1872 0.9916  -0.252  0.6264  False
#      P      R  -0.7622 0.0001 -1.2864 -0.2379   True
#      P      S  -0.5449 0.1985 -1.1779  0.0882  False
#      Q      R  -0.9493    0.0 -1.4186   -0.48   True
#      Q      S   -0.732 0.0019 -1.3203 -0.1437   True
#      R      S   0.2173 0.9996  -0.437  0.8716  False
# ----------------------------------------------------
# Value Counts:
# C    9662
# H    3669
# G    2702
# Q    2376
# O    2361
# N    2289
# M    1954
# F    1934
# J    1795
# P    1327
# K    1290
# E    1094
# R    1087
# I    1052
# D     784
# S     593
# L     449
# B     367
# Name: nace, dtype: int64

# %% [markdown]
# ## 'lpk' (very high cardinality )

# %%
data2018ft['lpk1'] = data2018ft['lpk'] // 100
data2018ft['lpk2'] = data2018ft['lpk'] // 10
data2018ft
# Out:
#       nace  lpk  hourly_rate  esize_class_nc  gen_F  gen_M  age_class_nc  \
# 44952    C  722         8.13               0      0      1             0
# 44953    C  721         8.20               0      0      1             1
# 44954    C  722         8.20               0      0      1             0
# 44955    C  334         2.51               0      1      0             1
# 44956    M  522         2.19               1      1      0             1
# ...    ...  ...          ...             ...    ...    ...           ...
# 88111    N  711         2.84               0      0      1             0
# 88112    N  711         2.84               0      0      1             0
# 88113    N  711         2.84               0      0      1             2
# 88114    N  711         2.84               0      0      1             0
# 88115    L  122        16.53               0      0      1             2
#
#        education_nc  lpk1  lpk2
# 44952             1     7    72
# 44953             1     7    72
# 44954             1     7    72
# 44955             1     3    33
# 44956             1     5    52
# ...             ...   ...   ...
# 88111             1     7    71
# 88112             1     7    71
# 88113             1     7    71
# 88114             1     7    71
# 88115             3     1    12
#
# [36785 rows x 10 columns]

# %%
data2018ft.value_counts('lpk1')
# Out:
# lpk1
# 2    9220
# 7    5817
# 8    5807
# 3    4363
# 1    3486
# 5    3296
# 9    2902
# 4    1622
# 0     263
# 6       9
# dtype: int64

# %%
hr_in_categories(data2018ft, 'lpk1')
# Out:
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =====================================================
# group1 group2 meandiff p-adj   lower    upper  reject
# -----------------------------------------------------
#      0      1   3.4329    0.0   2.7481  4.1178   True
#      0      2   0.7759 0.0093   0.1062  1.4457   True
#      0      3   -0.944 0.0005   -1.624  -0.264   True
#      0      4   -1.731    0.0  -2.4429  -1.019   True
#      0      5  -2.6345    0.0  -3.3208 -1.9483   True
#      0      6  -3.0919 0.1757  -6.7225  0.5387  False
#      0      7  -1.5342    0.0  -2.2094  -0.859   True
#      0      8  -1.6952    0.0  -2.3704   -1.02   True
#      0      9  -3.0173    0.0  -3.7069 -2.3276   True
#      1      2   -2.657    0.0    -2.87 -2.4441   True
#      1      3  -4.3769    0.0  -4.6202 -4.1336   True
#      1      4  -5.1639    0.0  -5.4858  -4.842   True
#      1      5  -6.0675    0.0  -6.3277 -5.8073   True
#      1      6  -6.5248    0.0 -10.0995 -2.9502   True
#      1      7  -4.9671    0.0  -5.1965 -4.7377   True
#      1      8  -5.1282    0.0  -5.3576 -4.8987   True
#      1      9  -6.4502    0.0  -6.7193 -6.1811   True
#      2      3  -1.7199    0.0  -1.9167 -1.5231   True
#      2      4  -2.5069    0.0  -2.7953 -2.2185   True
#      2      5  -3.4105    0.0  -3.6278 -3.1931   True
#      2      6  -3.8678 0.0217  -7.4396 -0.2961   True
#      2      7  -2.3101    0.0  -2.4895 -2.1308   True
#      2      8  -2.4712    0.0  -2.6506 -2.2917   True
#      2      9  -3.7932    0.0  -4.0212 -3.5652   True
#      3      4   -0.787    0.0  -1.0985 -0.4755   True
#      3      5  -1.6906    0.0  -1.9377 -1.4434   True
#      3      6  -2.1479 0.6681  -5.7216  1.4258  False
#      3      7  -0.5902    0.0  -0.8047 -0.3757   True
#      3      8  -0.7513    0.0  -0.9658 -0.5367   True
#      3      9  -2.0733    0.0  -2.3298 -1.8167   True
#      4      5  -0.9036    0.0  -1.2284 -0.5787   True
#      4      6  -1.3609 0.9721  -4.9408   2.219  False
#      4      7   0.1968 0.5488   -0.104  0.4975  False
#      4      8   0.0357    1.0   -0.265  0.3365  False
#      4      9  -1.2863    0.0  -1.6183 -0.9543   True
#      5      6  -0.4574    1.0  -4.0323  3.1175  False
#      5      7   1.1003    0.0   0.8668  1.3338   True
#      5      8   0.9393    0.0   0.7057  1.1729   True
#      5      9  -0.3827 0.0004  -0.6554 -0.1101   True
#      6      7   1.5577 0.9337  -2.0151  5.1305  False
#      6      8   1.3967 0.9665  -2.1761  4.9695  False
#      6      9   0.0747    1.0  -3.5009  3.6502  False
#      7      8   -0.161 0.2348  -0.3597  0.0377  False
#      7      9  -1.4831    0.0  -1.7265 -1.2396   True
#      8      9   -1.322    0.0  -1.5655 -1.0786   True
# -----------------------------------------------------
# Value Counts:
# 2    9220
# 7    5817
# 8    5807
# 3    4363
# 1    3486
# 5    3296
# 9    2902
# 4    1622
# 0     263
# 6       9
# Name: lpk1, dtype: int64

# %% [markdown]
#  Remove classes with small mumber of cases: lpk1 == 6 "Qualified agricultural, forestry and fisheries workers" and lpk1 == 0 "Professions of the armed forces".
# Classes lpk1 4 (Clerical support workers), 7 (Craft and related trades workers) and 8 (Plant and machine operators, and assemblers) can be joined to one group.

# %%
data2018ft.drop(data2018ft[(data2018ft.lpk1 == 6) | (data2018ft.lpk1 == 0) ].index, inplace=True)
reclassify = { 1: 100, 2: 200, 3: 300, 4: 478, 5: 500, 7: 478, 8: 478, 9: 900}
data2018ft['lpk1_nc']=data2018ft['lpk1'].map(reclassify)

# %%
sns.boxplot(data=data2018ft, x='lpk1_nc', y='hourly_rate')
plt.ylim(0, 30);

# %% [markdown]
# ### Upper 'hourly_rate' outlier flag by 'lpk1_nc'

# %%
def outlier_iqr_upper(x, n=1.5):
    """ check if x is outlier using IQR"""
    iqr = x.quantile(0.75)-x.quantile(0.25)
    upper_lim = x.quantile(0.75)+iqr*n
    return x>=upper_lim

# %%
data2018ft['outlier_iqr_lpk1_nc'] = data2018ft.groupby('lpk1_nc')['hourly_rate'].apply(outlier_iqr_upper, n=1.5)
sns.boxplot(data=data2018ft.query('outlier_iqr_lpk1_nc ==False'), x='lpk1_nc', y='hourly_rate')
plt.ylim(0, 30);

# %%
data2018ft.groupby('lpk1_nc')['outlier_iqr_lpk1_nc'].value_counts()
# Out:
# lpk1_nc  outlier_iqr_lpk1_nc
# 100      False                   3267
#          True                     219
# 200      False                   8706
#          True                     514
# 300      False                   4251
#          True                     112
# 478      False                  12904
#          True                     342
# 500      False                   3148
#          True                     148
# 900      False                   2743
#          True                     159
# Name: outlier_iqr_lpk1_nc, dtype: int64

# %%
lpk_agg = data2018ft.groupby(['lpk1_nc', 'lpk2', 'lpk'])['hourly_rate'].agg(['mean', 'count', 'std']).reset_index()

# %%
sns.set_theme(rc={"figure.figsize":(6, 4)})

# %%
f, axes = plt.subplots(1, 2)
plt.subplots_adjust(wspace = 0.35)
sns.scatterplot(ax=axes[0], data=lpk_agg, x='lpk', y='mean', hue='lpk1_nc',
                 size='count',sizes=(40, 600), alpha=0.5, palette='Set1', legend=False)
sns.scatterplot(ax=axes[1], data=lpk_agg, x='lpk', y='count', hue='lpk1_nc', 
                s=50, alpha=0.5,palette='Set1')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.0);

# %%
sns.scatterplot(data=lpk_agg, x='mean', y='std', hue='lpk1_nc',
                 size='count',sizes=(40, 600), alpha=0.5, palette='Set1')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.0);

# %% [markdown]
# ## combined 'nace' and ('lpk1', 'lpk1_nc' or 'lpk2')

# %%
lpk1_nace_agg = data2018ft.groupby(['nace', 'lpk1'])['hourly_rate'].agg(['mean', 'count', 'std'])
lpk1_nace_agg.shape
# Out:
# (143, 3)

# %%
lpk1_nc_nace_agg = data2018ft.groupby(['nace', 'lpk1_nc'])['hourly_rate'].agg(['mean', 'count', 'std'])
lpk1_nc_nace_agg.shape
# Out:
# (108, 3)

# %%
lpk2_nace_agg = data2018ft.groupby(['nace', 'lpk2'])['hourly_rate'].agg(['mean', 'count', 'std'])
lpk2_nace_agg.shape
# Out:
# (532, 3)

# %%
f, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(13,5))
plt.subplots_adjust(wspace = 0.35)

ax1.plot(lpk1_nace_agg['count'].sort_values().values)
ax1.hlines(30, 0, len(lpk1_nace_agg), colors='red', linestyles='dashed')
ax1.text(25, 100, '30 cases ', ha='center', va='center')
ax1.set_ylabel('number of cases')
ax1.set_xlabel('rank')
ax1.set_title('lpk1')

ax2.plot(lpk1_nc_nace_agg['count'].sort_values().values)
ax2.hlines(30, 0, len(lpk1_nc_nace_agg), colors='red', linestyles='dashed')
ax2.text(25, 100, '30 cases ', ha='center', va='center')
ax2.set_ylabel('number of cases')
ax2.set_xlabel('rank')
ax2.set_title('lpk1_nc')

ax3.plot(lpk2_nace_agg['count'].sort_values().values)
ax3.hlines(30, 0, len(lpk2_nace_agg), colors='red', linestyles='dashed')
ax3.text(350, 100, '30 cases ', ha='center', va='center')
ax3.set_ylabel('number of cases')
ax3.set_xlabel('rank')
ax3.set_title('lpk2');

# %%
hr_mean = data2018ft.query('outlier_iqr_lpk1_nc ==False')['hourly_rate'].mean().round(2)
hr_mean
# Out:
# 5.1

# %%
f, (ax1, ax2, ax3) = plt.subplots(1, 3, sharey=True, figsize=(13,5))
plt.subplots_adjust(wspace = 0.1)

ax1.plot(lpk1_nace_agg['mean'].sort_values().values)
ax1.hlines(hr_mean, 0, len(lpk1_nace_agg), colors='red', linestyles='dashed')
ax1.text(len(lpk1_nace_agg)/2, hr_mean, f'Total hr mean:{hr_mean}', ha='center', va='bottom')
ax1.set_ylabel('mean')
ax1.set_xlabel('rank')
ax1.set_title('lpk1')

ax2.plot(lpk1_nc_nace_agg['mean'].sort_values().values)
ax2.hlines(hr_mean, 0, len(lpk1_nc_nace_agg), colors='red', linestyles='dashed')
ax2.text(len(lpk1_nc_nace_agg)/2, hr_mean, f'Total hr mean:{hr_mean}', ha='center', va='bottom')
ax2.set_xlabel('rank')
ax2.set_title('lpk1_nc')

ax3.plot(lpk2_nace_agg['mean'].sort_values().values)
ax3.hlines(hr_mean, 0, len(lpk2_nace_agg), colors='red', linestyles='dashed')
ax3.text(len(lpk2_nace_agg)/2, hr_mean, f'Total hr mean:{hr_mean}', ha='center', va='bottom')
ax3.set_xlabel('rank')
ax3.set_title('lpk2');

# %%
lpk1_nace_agg = data2018ft.groupby(['nace','lpk1'])['hourly_rate'].agg(['mean', 'count']).reset_index()
lpk1_nc_nace_agg = data2018ft.groupby(['nace','lpk1_nc'])['hourly_rate'].agg(['mean', 'count']).reset_index()
lpk2_nace_agg = data2018ft.groupby(['nace','lpk2'])['hourly_rate'].agg(['mean', 'count']).reset_index()

# %%
f, (ax1, ax2, ax3) = plt.subplots(1, 3, sharey=True, figsize=(16,8))
plt.subplots_adjust(wspace = 0.05)
norm=plt.Normalize(0, max(lpk2_nace_agg['mean']))
sc = ax1.scatter(data=lpk1_nace_agg, x='lpk1', y='nace', c='mean', s='count',cmap='CMRmap', norm=norm)
ax1.set_xlabel('lpk1')

ax2.scatter(data=lpk1_nc_nace_agg, x='lpk1_nc', y='nace', c='mean', s='count',cmap='CMRmap', norm=norm);
ax2.set_xlabel('lpk1_nc')

ax3.scatter(data=lpk2_nace_agg, x='lpk2', y='nace', c='mean', s='count',cmap='CMRmap', norm=norm);
ax3.set_xlabel('lpk2')

cbar_ax = f.add_axes([0.91, 0.15, 0.05, 0.7])
f.colorbar(sc, cax=cbar_ax);

# %%
lpk1_nc_nace_agg.query(f'count>5 & mean>{hr_mean}').sort_values('lpk1_nc').value_counts('lpk1_nc')/len(lpk1_nc_nace_agg['nace'].unique())*100
# Out:
# lpk1_nc
# 100    100.000000
# 200     94.444444
# 300     44.444444
# 478      5.555556
# 500      5.555556
# dtype: float64

# %%
lpk1_nc_nace_agg.query(f'count>5 & mean>{hr_mean}').sort_values('lpk1_nc')
# Out:
#     nace  lpk1_nc       mean  count
# 0      B      100  11.994103     39
# 102    S      100   7.632979     94
# 42     I      100   6.023010    103
# 60     L      100   7.346437     87
# 36     H      100   9.933043    230
# 30     G      100   8.230035    282
# 66     M      100  11.655250    280
# 24     F      100   8.854255    235
# 48     J      100  13.056420    176
# 18     E      100   8.321207    116
# 72     N      100   8.993949    157
# 12     D      100   9.630614    114
# 84     P      100   8.014897    145
# 6      C      100   9.491642    731
# 90     Q      100   8.013763     93
# 96     R      100   6.162519    135
# 78     O      100   9.359295    241
# 54     K      100  15.103158    228
# 73     N      200   6.801348    267
# 79     O      200   6.221567    823
# 67     M      200   6.968059   1149
# 85     P      200   5.746080    750
# 61     L      200   6.112468     77
# 55     K      200   8.923306    496
# 91     Q      200   6.526664   1301
# 43     I      200   5.277273     44
# 13     D      200   7.078645    214
# 1      B      200   5.950000     38
# 7      C      200   7.154530   1139
# 49     J      200   9.088248   1233
# 19     E      200   5.808027    147
# 103    S      200   5.920500    120
# 31     G      200   6.677614    394
# 37     H      200   6.929415    376
# 25     F      200   6.923582    201
# 20     E      300   5.223125    160
# 26     F      300   5.337339    124
# 14     D      300   5.937708     96
# 80     O      300   5.813679    549
# 8      C      300   5.706391    884
# 2      B      300   5.491667     36
# 56     K      300   5.944213    356
# 38     H      300   6.670425    259
# 3      B      478   5.392597    231
# 82     O      500   5.208357    353

# %% [markdown]
# Percentage of economy sectors (nace) above mean hr for first level (lpk1) of profession classification. In general, proffesion is more important than employment sector. Hr is highest in lpk1=1 (Managers) and  lpk1=2 (Professionals) profession class and lowest in lpk1=5 (Service and sales workers) and lpk1=9 (Elementary occupations). For the same profession hr tends to be higher in nace=K (Financial and insurance activities), nace=J (Information and communications) and nace=M (Professional, scientific and technical activities) sectors.

# %%
reclassify = { 'K': 1, 'J': 1,'M': 1}
data2018ft['nace_nc']=data2018ft['nace'].map(reclassify)
data2018ft['nace_nc'].fillna(0, inplace = True)
data2018ft['nace_nc'] = data2018ft['nace_nc'].astype(int)

# %%
data2018ft
# Out:
#       nace  lpk  hourly_rate  esize_class_nc  gen_F  gen_M  age_class_nc  \
# 44952    C  722         8.13               0      0      1             0
# 44953    C  721         8.20               0      0      1             1
# 44954    C  722         8.20               0      0      1             0
# 44955    C  334         2.51               0      1      0             1
# 44956    M  522         2.19               1      1      0             1
# ...    ...  ...          ...             ...    ...    ...           ...
# 88111    N  711         2.84               0      0      1             0
# 88112    N  711         2.84               0      0      1             0
# 88113    N  711         2.84               0      0      1             2
# 88114    N  711         2.84               0      0      1             0
# 88115    L  122        16.53               0      0      1             2
#
#        education_nc  lpk1  lpk2  lpk1_nc  outlier_iqr_lpk1_nc  nace_nc
# 44952             1     7    72      478                False        0
# 44953             1     7    72      478                False        0
# 44954             1     7    72      478                False        0
# 44955             1     3    33      300                False        0
# 44956             1     5    52      500                False        1
# ...             ...   ...   ...      ...                  ...      ...
# 88111             1     7    71      478                False        0
# 88112             1     7    71      478                False        0
# 88113             1     7    71      478                False        0
# 88114             1     7    71      478                False        0
# 88115             3     1    12      100                False        0
#
# [36513 rows x 13 columns]

# %%
data2018ft.to_csv('../Data/LT_DU_data_for_ML.csv', index=False)
