# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] ='3'

# %%
data_import = pd.read_csv('../Data/SQLout_employees.csv')

# %%
data = data_import.query('arrangement == "FT" & year==2018', inplace=False )[['nace', 
                          'esize_class', 'gender', 
                          'age_class', 'lpk',  'education','experience', 'hourly_rate' ]]
data = data.rename(columns={'hourly_rate': 'target'})
data.shape
# Out:
# (36785, 8)

# %%
def outlier_iqr_upper(x, n=1.5):
    """ check if x is outlier using IQR"""
    iqr = x.quantile(0.75)-x.quantile(0.25)
    upper_lim = x.quantile(0.75)+iqr*n
    return x>=upper_lim

# %%
data['lpk2'] = data['lpk'] // 10
data['outlier'] = data.groupby('lpk2')['target'].apply(outlier_iqr_upper, n=1.0)
data=data.query('outlier==False')
data = data.drop(columns=['outlier', 'lpk2'])
data['lpk'] = data['lpk'].apply(str)

# %%
dataset=data.copy()
print(dataset.shape)
dataset.head()
# Out:
# (34259, 8)
#       nace esize_class gender age_class  lpk education  experience  target
# 44952    C        1_49      M     50-59  722        G2          13    8.13
# 44953    C        1_49      M     40-49  721        G2          13    8.20
# 44954    C        1_49      M     50-59  722        G2          13    8.20
# 44955    C        1_49      F     40-49  334        G2           0    2.51
# 44956    M      50_249      F     40-49  522        G2          18    2.19

# %% [markdown]
# ## Datasets

# %%
train_dataset = dataset.sample(frac=0.8, random_state=99)
test_dataset = dataset.drop(train_dataset.index)
train_target = train_dataset.pop("target")
test_target = test_dataset.pop("target")

# %%
train_ltdu_features_dict = {name: np.array(value) for name, value in train_dataset.items()}
test_ltdu_features_dict = {name: np.array(value) for name, value in test_dataset.items()}

# %% [markdown]
# # Feature preprocessing

# %%
inputs = {}
for name, column in train_dataset.items():
  dtype = column.dtype
  if dtype == object:
    dtype = tf.string
  else:
    dtype = tf.float32

  inputs[name] = tf.keras.Input(shape=(1,), name=name, dtype=dtype)
inputs
# Out:
# {'nace': <KerasTensor: shape=(None, 1) dtype=string (created by layer 'nace')>,
#  'esize_class': <KerasTensor: shape=(None, 1) dtype=string (created by layer 'esize_class')>,
#  'gender': <KerasTensor: shape=(None, 1) dtype=string (created by layer 'gender')>,
#  'age_class': <KerasTensor: shape=(None, 1) dtype=string (created by layer 'age_class')>,
#  'lpk': <KerasTensor: shape=(None, 1) dtype=string (created by layer 'lpk')>,
#  'education': <KerasTensor: shape=(None, 1) dtype=string (created by layer 'education')>,
#  'experience': <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'experience')>}

# %%
numeric_inputs = {name:input for name, input in inputs.items()
                  if input.dtype==tf.float32}

x = tf.keras.layers.Concatenate()(list(numeric_inputs.values()))
norm = tf.keras.layers.Normalization()
norm.adapt(np.array(train_dataset[numeric_inputs.keys()]))
all_numeric_inputs = norm(x)

# %%
preprocessed_inputs = [all_numeric_inputs]

# %%
for name, input in inputs.items():
  if input.dtype == tf.float32:
    continue

  lookup = tf.keras.layers.StringLookup(vocabulary=np.unique(train_dataset[name]))
  one_hot = tf.keras.layers.CategoryEncoding(num_tokens=lookup.vocabulary_size())

  x = lookup(input)
  x = one_hot(x)
  preprocessed_inputs.append(x)

# %%
preprocessed_inputs
# Out:
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'normalization_1')>,
#  <KerasTensor: shape=(None, 19) dtype=float32 (created by layer 'category_encoding_6')>,
#  <KerasTensor: shape=(None, 4) dtype=float32 (created by layer 'category_encoding_7')>,
#  <KerasTensor: shape=(None, 3) dtype=float32 (created by layer 'category_encoding_8')>,
#  <KerasTensor: shape=(None, 6) dtype=float32 (created by layer 'category_encoding_9')>,
#  <KerasTensor: shape=(None, 118) dtype=float32 (created by layer 'category_encoding_10')>,
#  <KerasTensor: shape=(None, 5) dtype=float32 (created by layer 'category_encoding_11')>]

# %%
preprocessed_inputs_cat = tf.keras.layers.Concatenate()(preprocessed_inputs)
ltdu_preprocessing = tf.keras.Model(inputs, preprocessed_inputs_cat)

# %% [markdown]
# # Model and predictions

# %%
def ltdu_model(preprocessing_head, inputs):
  body = tf.keras.Sequential([
    tf.keras.layers.Dense(64),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(1)
  ])

  preprocessed_inputs = preprocessing_head(inputs)
  result = body(preprocessed_inputs)
  model = tf.keras.Model(inputs, result)

  model.compile(loss=tf.keras.losses.MeanSquaredError(),
                optimizer=tf.keras.optimizers.Adam(),
                metrics=[tf.keras.metrics.RootMeanSquaredError()]),
  return model

ltdu_model = ltdu_model(ltdu_preprocessing, inputs)

# %%
tf.keras.utils.plot_model(ltdu_model, rankdir="TB", show_shapes=True)

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(
    min_delta=0.001,
    patience=10, 
    restore_best_weights=True,
)

# %%
history =ltdu_model.fit(x=train_ltdu_features_dict,
                        y=train_target,
                        epochs=50,
                        validation_split = 0.2,
                        callbacks=[early_stopping])
# Out:
# Epoch 1/50
# 686/686 [==============================] - 9s 11ms/step - loss: 5.3532 - root_mean_squared_error: 2.3137 - val_loss: 3.3007 - val_root_mean_squared_error: 1.8168
# Epoch 2/50
# 686/686 [==============================] - 7s 10ms/step - loss: 3.6141 - root_mean_squared_error: 1.9011 - val_loss: 3.2156 - val_root_mean_squared_error: 1.7932
# Epoch 3/50
# 686/686 [==============================] - 7s 10ms/step - loss: 3.5233 - root_mean_squared_error: 1.8771 - val_loss: 3.2103 - val_root_mean_squared_error: 1.7917
# Epoch 4/50
# 686/686 [==============================] - 7s 10ms/step - loss: 3.5134 - root_mean_squared_error: 1.8744 - val_loss: 3.1998 - val_root_mean_squared_error: 1.7888
# Epoch 5/50
# 686/686 [==============================] - 7s 10ms/step - loss: 3.4839 - root_mean_squared_error: 1.8665 - val_loss: 3.1832 - val_root_mean_squared_error: 1.7842
# Epoch 6/50
# 686/686 [==============================] - 7s 11ms/step - loss: 3.4752 - root_mean_squared_error: 1.8642 - val_loss: 3.1921 - val_root_mean_squared_error: 1.7866
# Epoch 7/50
# 686/686 [==============================] - 7s 10ms/step - loss: 3.4658 - root_mean_squared_error: 1.8617 - val_loss: 3.1829 - val_root_mean_squared_error: 1.7841
# Epoch 8/50
# 686/686 [==============================] - 7s 11ms/step - loss: 3.4619 - root_mean_squared_error: 1.8606 - val_loss: 3.1901 - val_root_mean_squared_error: 1.7861
# Epoch 9/50
# 686/686 [==============================] - 7s 11ms/step - loss: 3.4545 - root_mean_squared_error: 1.8586 - val_loss: 3.1900 - val_root_mean_squared_error: 1.7860
# Epoch 10/50
# 686/686 [==============================] - 7s 10ms/step - loss: 3.4384 - root_mean_squared_error: 1.8543 - val_loss: 3.2119 - val_root_mean_squared_error: 1.7922
# Epoch 11/50
# 686/686 [==============================] - 7s 10ms/step - loss: 3.4231 - root_mean_squared_error: 1.8502 - val_loss: 3.1754 - val_root_mean_squared_error: 1.7820
# Epoch 12/50
# 686/686 [==============================] - 7s 10ms/step - loss: 3.4078 - root_mean_squared_error: 1.8460 - val_loss: 3.1851 - val_root_mean_squared_error: 1.7847
# Epoch 13/50
# 686/686 [==============================] - 7s 10ms/step - loss: 3.4198 - root_mean_squared_error: 1.8493 - val_loss: 3.1998 - val_root_mean_squared_error: 1.7888
# Epoch 14/50
# 686/686 [==============================] - 7s 10ms/step - loss: 3.4249 - root_mean_squared_error: 1.8507 - val_loss: 3.1826 - val_root_mean_squared_error: 1.7840
# Epoch 15/50
# 686/686 [==============================] - 7s 10ms/step - loss: 3.4154 - root_mean_squared_error: 1.8481 - val_loss: 3.1813 - val_root_mean_squared_error: 1.7836
# Epoch 16/50
# 686/686 [==============================] - 7s 10ms/step - loss: 3.4019 - root_mean_squared_error: 1.8444 - val_loss: 3.2271 - val_root_mean_squared_error: 1.7964
# Epoch 17/50
# 686/686 [==============================] - 7s 10ms/step - loss: 3.3978 - root_mean_squared_error: 1.8433 - val_loss: 3.1846 - val_root_mean_squared_error: 1.7845
# Epoch 18/50
# 686/686 [==============================] - 7s 10ms/step - loss: 3.4020 - root_mean_squared_error: 1.8445 - val_loss: 3.1677 - val_root_mean_squared_error: 1.7798
# Epoch 19/50
# 686/686 [==============================] - 7s 11ms/step - loss: 3.3962 - root_mean_squared_error: 1.8429 - val_loss: 3.1899 - val_root_mean_squared_error: 1.7860
# Epoch 20/50
# 686/686 [==============================] - 7s 11ms/step - loss: 3.4111 - root_mean_squared_error: 1.8469 - val_loss: 3.1932 - val_root_mean_squared_error: 1.7869
# Epoch 21/50
# 686/686 [==============================] - 7s 11ms/step - loss: 3.3880 - root_mean_squared_error: 1.8407 - val_loss: 3.1616 - val_root_mean_squared_error: 1.7781
# Epoch 22/50
# 686/686 [==============================] - 7s 10ms/step - loss: 3.3552 - root_mean_squared_error: 1.8317 - val_loss: 3.1860 - val_root_mean_squared_error: 1.7849
# Epoch 23/50
# 686/686 [==============================] - 7s 10ms/step - loss: 3.3757 - root_mean_squared_error: 1.8373 - val_loss: 3.1658 - val_root_mean_squared_error: 1.7793
# Epoch 24/50
# 686/686 [==============================] - 7s 10ms/step - loss: 3.3837 - root_mean_squared_error: 1.8395 - val_loss: 3.1918 - val_root_mean_squared_error: 1.7866
# Epoch 25/50
# 686/686 [==============================] - 7s 10ms/step - loss: 3.3691 - root_mean_squared_error: 1.8355 - val_loss: 3.1634 - val_root_mean_squared_error: 1.7786
# Epoch 26/50
# 686/686 [==============================] - 7s 11ms/step - loss: 3.3586 - root_mean_squared_error: 1.8326 - val_loss: 3.1928 - val_root_mean_squared_error: 1.7868
# Epoch 27/50
# 686/686 [==============================] - 7s 11ms/step - loss: 3.3609 - root_mean_squared_error: 1.8333 - val_loss: 3.1883 - val_root_mean_squared_error: 1.7856
# Epoch 28/50
# 686/686 [==============================] - 8s 11ms/step - loss: 3.3512 - root_mean_squared_error: 1.8306 - val_loss: 3.1671 - val_root_mean_squared_error: 1.7796
# Epoch 29/50
# 686/686 [==============================] - 7s 11ms/step - loss: 3.3607 - root_mean_squared_error: 1.8332 - val_loss: 3.1707 - val_root_mean_squared_error: 1.7806
# Epoch 30/50
# 686/686 [==============================] - 7s 11ms/step - loss: 3.3625 - root_mean_squared_error: 1.8337 - val_loss: 3.1623 - val_root_mean_squared_error: 1.7783
# Epoch 31/50
# 686/686 [==============================] - 7s 11ms/step - loss: 3.3464 - root_mean_squared_error: 1.8293 - val_loss: 3.1703 - val_root_mean_squared_error: 1.7805

# %%
history_df = pd.DataFrame(history.history)
history_df.loc[1:, ['root_mean_squared_error', 'val_root_mean_squared_error']].plot();
print("Minimum validation RMSE: {}".format(history_df['val_root_mean_squared_error'].min()))
# Out:
# Minimum validation RMSE: 1.7780945301055908

# %%
loss, rmse =ltdu_model.evaluate(x=test_ltdu_features_dict, y=test_target)
print("RMSE", rmse)
# Out:
# 215/215 [==============================] - 2s 8ms/step - loss: 3.1772 - root_mean_squared_error: 1.7825
# RMSE 1.7824798822402954
